# %% [markdown]
# <a href="https://colab.research.google.com/github/Faareh-Ahmed/Segment-Green-Spaces/blob/main/PointPrompts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -U segment-geospatial

# %%
import leafmap
from samgeo import SamGeo2, regularize

# %%
m = leafmap.Map(center=[33.679699, 72.939091], zoom=12, height="800px")
m.add_basemap("Satellite")
m
# Out:
# Map(center=[33.679699, 72.939091], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
# if m.user_roi is not None:
#     bbox = m.user_roi_bounds()
# else:
bbox = [-117.6029, 47.65, -117.5936, 47.6563]

bbox
# Out:
# [-117.6029, 47.65, -117.5936, 47.6563]

# %%
image = "satellite.tif"
leafmap.map_tiles_to_geotiff(
    output=image, bbox=bbox, zoom=18, source="Satellite", overwrite=True
)
# Out:
# Downloaded image 1/56
# Downloaded image 2/56
# Downloaded image 3/56
# Downloaded image 4/56
# Downloaded image 5/56
# Downloaded image 6/56
# Downloaded image 7/56
# Downloaded image 8/56
# Downloaded image 9/56
# Downloaded image 10/56
# Downloaded image 11/56
# Downloaded image 12/56
# Downloaded image 13/56
# Downloaded image 14/56
# Downloaded image 15/56
# Downloaded image 16/56
# Downloaded image 17/56
# Downloaded image 18/56
# Downloaded image 19/56
# Downloaded image 20/56
# Downloaded image 21/56
# Downloaded image 22/56
# Downloaded image 23/56
# Downloaded image 24/56
# Downloaded image 25/56
# Downloaded image 26/56
# Downloaded image 27/56
# Downloaded image 28/56
# Downloaded image 29/56
# Downloaded image 30/56
# Downloaded image 31/56
# Downloaded image 32/56
# Downloaded image 33/56
# Downloaded image 34/56
# Downloaded image 35/56
# Downloaded image 36/56
# Downloaded image 37/56
# Downloaded image 38/56
# Downloaded image 39/56
# Downloaded image 40/56
# ...

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=420396.0, center=[47.65315, -117.59825000000001], controls=(ZoomControl(options=['position', 'zoom_…

# %%
sam = SamGeo2(
    model_id="sam2-hiera-large",
    automatic=False,
)

# %%
sam.set_image(image)

# %%
if m.user_rois is not None:
    point_coords_batch = m.user_rois
else:
    point_coords_batch = [
        [-117.599896, 47.655345],
        [-117.59992, 47.655167],
        [-117.599928, 47.654974],
        [-117.599518, 47.655337],
    ]

point_coords_batch
# Out:
# [[-117.599896, 47.655345],
#  [-117.59992, 47.655167],
#  [-117.599928, 47.654974],
#  [-117.599518, 47.655337]]

# %%
sam.predict_by_points(
    point_coords_batch=point_coords_batch,
    point_labels=None,
    point_crs="EPSG:4326",
    output="mask.tif",
    dtype="uint8",
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-59-6a3e65bdde88> in <cell line: 1>()
# ----> 1 sam.predict_by_points(
#       2     point_coords_batch=point_coords_batch,
#       3     point_labels=None,
#       4     point_crs="EPSG:4326",
#       5     output="mask.tif",
#
# /usr/local/lib/python3.10/dist-packages/samgeo/samgeo2.py in predict_by_points(self, point_coords_batch, point_labels_batch, box_batch, mask_input_batch, multimask_output, return_logits, normalize_coords, point_crs, output, index, unique, mask_multiplier, dtype, return_results, **kwargs)
#     808         predictor = self.predictor
#     809
# --> 810         masks_batch, scores_batch, logits_batch = predictor.predict_batch(
#     811             point_coords_batch=[points],
#     812             point_labels_batch=[labels],
#
# ...
