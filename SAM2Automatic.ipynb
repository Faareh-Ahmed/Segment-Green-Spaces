# %% [markdown]
# <a href="https://colab.research.google.com/github/Faareh-Ahmed/Segment-Green-Spaces/blob/main/SAM2Automatic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -U segment-geospatial

# %%
import leafmap
from samgeo import SamGeo2

# %%
m = leafmap.Map(center=[33.687698, 72.926731], zoom=19)
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[33.687698, 72.926731], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-95.3704, 29.6762, -95.368, 29.6775]

bbox
# Out:
# [72.9793, 33.6933, 72.9836, 33.6963]

# %%
image = "satellite.tif"
leafmap.map_tiles_to_geotiff(
    output=image, bbox=bbox, zoom=20, source="Satellite", overwrite=True
)
# Out:
# Downloaded image 1/154
# Downloaded image 2/154
# Downloaded image 3/154
# Downloaded image 4/154
# Downloaded image 5/154
# Downloaded image 6/154
# Downloaded image 7/154
# Downloaded image 8/154
# Downloaded image 9/154
# Downloaded image 10/154
# Downloaded image 11/154
# Downloaded image 12/154
# Downloaded image 13/154
# Downloaded image 14/154
# Downloaded image 15/154
# Downloaded image 16/154
# Downloaded image 17/154
# Downloaded image 18/154
# Downloaded image 19/154
# Downloaded image 20/154
# Downloaded image 21/154
# Downloaded image 22/154
# Downloaded image 23/154
# Downloaded image 24/154
# Downloaded image 25/154
# Downloaded image 26/154
# Downloaded image 27/154
# Downloaded image 28/154
# Downloaded image 29/154
# Downloaded image 30/154
# Downloaded image 31/154
# Downloaded image 32/154
# Downloaded image 33/154
# Downloaded image 34/154
# Downloaded image 35/154
# Downloaded image 36/154
# Downloaded image 37/154
# Downloaded image 38/154
# ...

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=13438509.0, center=[33.6948, 72.98145], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
sam2 = SamGeo2(model_id="sam2-hiera-large", automatic=True)
# Out:
# sam2_hiera_large.pt:   0%|          | 0.00/898M [00:00<?, ?B/s]

# %%
sam2.generate(image)

# %%
sam2.save_masks(output="masks.tif")

# %%
sam2.show_masks(cmap="binary_r")

# %%
sam2.show_anns(axis="off", alpha=0.7, output="annotations.tif")
